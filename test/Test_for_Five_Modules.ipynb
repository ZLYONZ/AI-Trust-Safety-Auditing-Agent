# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %% [markdown]
# # **Connect to github and update it**

# %%
# !git clone https://github.com/ZLYONZ/AI-Trust-Safety-Auditing-Agent.git
# Out:
# Cloning into 'AI-Trust-Safety-Auditing-Agent'...
# remote: Enumerating objects: 11730, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 11730 (delta 96), reused 18 (delta 18), pack-reused 11599 (from 2)
# Receiving objects: 100% (11730/11730), 23.65 MiB | 17.73 MiB/s, done.
# Resolving deltas: 100% (6130/6130), done.
# Updating files: 100% (11594/11594), done.

# %%
# %cd /content/AI-Trust-Safety-Auditing-Agent
# !git pull
# Out:
# /content/AI-Trust-Safety-Auditing-Agent
# Already up to date.

# %% [markdown]
# # **Governance**

# %%
# %cd /content/AI-Trust-Safety-Auditing-Agent/five-modules/goveronance
# !ls
# Out:
# /content/AI-Trust-Safety-Auditing-Agent/five-modules/goveronance
# document_loader.py    governance_prompt.py  governance_schema.py   test.py
# governance_module.py  governance_rules.py   governance_scoring.py

# %%
document_text = """
TTMT has established a formal AI governance framework to oversee the development and deployment of its machine learning systems.

The company maintains a documented AI governance policy that defines key principles such as accountability, risk management, data privacy, and regulatory compliance. The policy outlines roles and responsibilities across business, risk, and technology teams, and is reviewed periodically, although not always on a strictly annual basis.

TTMT has implemented an internal AI risk management system aligned with general industry practices. The company maintains a risk register that identifies several categories of AI-related risks, including model bias, data quality issues, and operational risks. Risk mitigation controls are defined, and risk monitoring is conducted on a recurring basis, although documentation of alignment with formal frameworks such as NIST AI RMF is not always explicit.

To support internal controls, TTMT has documented a number of governance and compliance controls. Some controls are mapped to internal risk frameworks and are periodically tested. However, testing frequency may vary across teams, and documentation is not always standardized.

The company maintains an inventory of its AI systems, including information about system purpose, ownership, and deployment status. While most systems are included, updates to the inventory may not always occur in real time.

TTMT provides training programs related to AI governance and compliance. A majority of relevant personnel have completed training, and assessments are conducted to evaluate understanding. However, coverage is not fully comprehensive across all departments.

For GDPR compliance, TTMT maintains records of processing activities (ROPA) for its AI systems. These records include key information such as processing purpose, data categories, and retention policies. However, some records may not be updated within the most recent 12-month period, and DPO review is not consistently documented.

The company has established a Data Protection Impact Assessment (DPIA) process for high-risk AI systems. DPIAs are conducted in certain cases, and findings are documented. In some instances, DPO consultation and governance committee review are performed, but these processes are not fully standardized. Remediation actions are tracked, though not always systematically.

Overall, TTMT demonstrates a structured approach to AI governance and compliance, but there are areas where processes could be further formalized and consistently applied.
"""

# %%
from governance_module import GovernanceModule

# -----------------------------
# Run Governance Module
# -----------------------------
module = GovernanceModule()

result = module.run(document_text)

# -----------------------------
# Print Full Result
# -----------------------------
print("=== GOVERNANCE MODULE RESULT ===")
print(result.model_dump())

# -----------------------------
# Print Summary
# -----------------------------
print("\n=== MODULE SUMMARY ===")
print("Module:", result.module_id)
print("Score:", result.module_score)
print("Risk Level:", result.risk_level)

# -----------------------------
# Print Findings
# -----------------------------
print("\n=== FINDINGS ===")

for f in result.findings:
    print("Criterion:", f.criterion_id)
    print("Score:", f.score)
    print("Evidence ID:", f.evidence.evidence_id)
    print("Evidence Type:", f.evidence.evidence_type)
    print("Excerpt:", f.evidence.excerpt)
    print("Source Section:", f.evidence.source_section)
    print("Severity:", f.severity)
    print("---")
# Out:
# LLM RAW OUTPUT:
# {
#   "findings": [
#     {
#       "criterion_id": "G1.1",
#       "description": "AI Governance Policy",
#       "score": 0.75,
#       "evidence": {
#         "evidence_id": "G1.1",
#         "evidence_type": "policy_text",
#         "excerpt": "The company maintains a documented AI governance policy that defines key principles such as accountability, risk management, data privacy, and regulatory compliance. The policy outlines roles and responsibilities across business, risk, and technology teams, and is reviewed periodically, although not always on a strictly annual basis.",
#         "source_section": "Paragraph 1"
#       }
#     },
#     {
#       "criterion_id": "G1.2",
#       "description": "AI Risk Management System",
#       "score": 0.75,
#       "evidence": {
#         "evidence_id": "G1.2",
#         "evidence_type": "risk_management_text",
# ...

# %% [markdown]
# # **Fairness**

# %%
# %cd /content/AI-Trust-Safety-Auditing-Agent/five-modules/fairness
# !ls
# Out:
# /content/AI-Trust-Safety-Auditing-Agent/five-modules/fairness
# fairness_module.py  fairness_rules.py	fairness_scoring.py
# fairness_prompt.py  fairness_schema.py

# %%
document_text = """
AI System Fairness and Compliance Policy

Our organization is committed to building fair, transparent, and accountable AI systems. We implement standardized fairness evaluation metrics, including demographic parity, equal opportunity, and disparate impact analysis, to continuously monitor model performance across protected and non-protected groups.

We strictly prohibit the use of sensitive personal data such as race, ethnicity, religion, and health information unless explicitly required by law and supported by documented user consent. All datasets undergo automated and manual screening to remove or appropriately handle protected attributes before model training.

We conduct regular and standardized bias audits across all AI systems on a quarterly basis. These audits are centrally governed and documented, with clear thresholds for acceptable fairness levels. When bias is detected, mitigation strategies such as reweighting, resampling, and model retraining are systematically applied.

To ensure transparency, we provide both system-level and decision-level explainability. Users are able to understand how key features influence model outputs, and explanations are accessible through user-facing interfaces.

Our data practices fully comply with global privacy regulations, including GDPR and CCPA. We maintain clear data governance policies, and users can request access, correction, or deletion of their data at any time. These requests are processed within 7 days.

Additionally, fairness performance is continuously monitored in production environments, and alerts are triggered if performance deviates from predefined fairness thresholds. All fairness-related processes are documented and subject to internal audit and external review.
"""

# %%
from fairness_module import FairnessModule

# -----------------------------
# Run Fairness Module
# -----------------------------
module = FairnessModule()

result = module.run(document_text)

# -----------------------------
# Print Full Result
# -----------------------------
print("=== FAIRNESS MODULE RESULT ===")
print(result.model_dump())

# -----------------------------
# Print Summary
# -----------------------------
print("\n=== MODULE SUMMARY ===")
print("Module:", result.module_id)
print("Score:", result.module_score)
print("Risk Level:", result.risk_level)

# -----------------------------
# Print Findings
# -----------------------------
print("\n=== FINDINGS ===")

for f in result.findings:
    print("Criterion:", f.criterion_id)
    print("Score:", f.score)
    print("Evidence ID:", f.evidence.evidence_id)
    print("Evidence Type:", f.evidence.evidence_type)
    print("Excerpt:", f.evidence.excerpt)
    print("Source Section:", f.evidence.source_section)
    print("Severity:", f.severity)
    print("---")
# Out:
# LLM RAW OUTPUT:
# {
#   "findings": [
#     {
#       "criterion_id": "F2.1",
#       "description": "Fairness Metrics & Special Category Data",
#       "score": 1.0,
#       "evidence": {
#         "evidence_id": "F2.1",
#         "evidence_type": "policy_text",
#         "excerpt": "We strictly prohibit the use of sensitive personal data such as race, ethnicity, religion, and health information unless explicitly required by law and supported by documented user consent. All datasets undergo automated and manual screening to remove or appropriately handle protected attributes before model training.",
#         "source_section": "AI System Fairness and Compliance Policy"
#       }
#     },
#     {
#       "criterion_id": "F2.2",
#       "description": "Bias Monitoring System effectiveness",
#       "score": 0.75,
#       "evidence": {
#         "evidence_id": "F2.2",
#         "evidence_type": "policy_text",
# ...

# %% [markdown]
# # **Security**

# %%
# %cd /content/AI-Trust-Safety-Auditing-Agent/five-modules/security
# !ls
# Out:
# /content/AI-Trust-Safety-Auditing-Agent/five-modules/security
# AI-Trust-Safety-Auditing-Agent	security_prompt.py  security_scoring.py
# __pycache__			security_rules.py
# security_module.py		security_schema.py

# %%
document_text = """
TTMT is a global technology company that develops AI-powered recommendation, risk scoring, and automation systems. The company has implemented a mature and comprehensive security and adversarial robustness framework to safeguard its AI systems.

For access control, TTMT enforces strict role-based access control (RBAC) combined with attribute-based access control (ABAC) for sensitive operations. Multi-factor authentication (MFA) is mandatory across all internal systems. Access permissions are reviewed quarterly through a formal audit process, and all access activities are logged and monitored in real time.

In terms of data protection, TTMT encrypts all data at rest using AES-256 and secures data in transit via TLS 1.3. Sensitive data, including personally identifiable information (PII), is fully tokenized or anonymized before being used in model training pipelines. Data access is restricted through secure data environments with strict governance policies.

TTMT has established a dedicated adversarial robustness program. The company conducts regular adversarial testing, including stress testing under noisy inputs, adversarial perturbation simulations, and red-teaming exercises to identify vulnerabilities such as model evasion and data poisoning risks. Findings from these tests are incorporated into model retraining and defense strategies.

For API security, TTMT implements secure authentication using OAuth 2.0 and API gateways. Rate limiting, anomaly detection, and behavioral monitoring are in place to detect and prevent abuse. All API interactions are logged centrally, and automated alerts are triggered for suspicious activity.

TTMT also maintains a comprehensive incident response framework specifically tailored for AI systems. This includes predefined procedures for handling model breaches, data leakage, and adversarial attacks. The company conducts regular incident response drills and continuously updates its response playbooks based on emerging threats.

Additionally, TTMT adopts a zero-trust security architecture and continuously monitors its systems using centralized security dashboards. Security policies are regularly updated in alignment with industry standards and evolving threat landscapes.

Overall, TTMT demonstrates a high level of maturity in AI system security, with strong capabilities in access control, encryption, adversarial resilience, API protection, and incident response.
"""

# %%
from security_module import SecurityModule

# -----------------------------
# Run Security Module
# -----------------------------
module = SecurityModule()

result = module.run(document_text)

# -----------------------------
# Print Full Result
# -----------------------------
print("=== SECURITY MODULE RESULT ===")
print(result.model_dump())

# -----------------------------
# Print Summary
# -----------------------------
print("\n=== MODULE SUMMARY ===")
print("Module:", result.module_id)
print("Score:", result.module_score)
print("Risk Level:", result.risk_level)

# -----------------------------
# Print Findings
# -----------------------------
print("\n=== FINDINGS ===")

for f in result.findings:
    print("Criterion:", f.criterion_id)
    print("Score:", f.score)
    print("Evidence ID:", f.evidence.evidence_id)
    print("Evidence Type:", f.evidence.evidence_type)
    print("Excerpt:", f.evidence.excerpt)
    print("Source Section:", f.evidence.source_section)
    print("Severity:", f.severity)
    print("---")
# Out:
# LLM RAW OUTPUT:
# {
#   "findings": [
#     {
#       "criterion_id": "S3.1",
#       "description": "Data Protection & Encryption",
#       "score": 1.0,
#       "evidence": {
#         "evidence_id": "S3.1",
#         "evidence_type": "policy_text",
#         "excerpt": "TTMT encrypts all data at rest using AES-256 and secures data in transit via TLS 1.3. Sensitive data, including personally identifiable information (PII), is fully tokenized or anonymized before being used in model training pipelines. Data access is restricted through secure data environments with strict governance policies.",
#         "source_section": "Data protection"
#       }
#     },
#     {
#       "criterion_id": "S3.2",
#       "description": "Adversarial Robustness",
#       "score": 1.0,
#       "evidence": {
#         "evidence_id": "S3.2",
#         "evidence_type": "policy_text",
# ...

# %% [markdown]
# # **Transparency**

# %%
# %cd /content/AI-Trust-Safety-Auditing-Agent/five-modules/transparency
# !ls
# Out:
# /content/AI-Trust-Safety-Auditing-Agent/five-modules/transparency
# transparency_module.py	transparency_rules.py	transparency_scoring.py
# transparency_prompt.py	transparency_schema.py

# %%
document_text = """
TTMT is a global technology company that deploys AI-driven recommendation and decision-making systems across multiple digital platforms. The company has established a highly mature explainability and transparency framework aligned with regulatory standards such as GDPR and CCPA.

For model explainability, TTMT implements SHAP-based explanations across all production machine learning models. Feature importance scores are generated for over 98% of automated decisions, and internal systems allow full traceability from outputs back to input features and training data. In addition, TTMT provides clear, plain language explanations to end users, describing the logic, significance, and potential consequences of automated decisions in compliance with GDPR Articles 13 and 14.

In terms of audit trail, TTMT logs 100% of AI-driven decisions, including inputs, outputs, and model metadata. All logs are stored in an immutable storage system using write-once-read-many (WORM) technology. Audit records are retained for at least 7 years and are centrally accessible for compliance reviews and regulatory audits.

Regarding model documentation, TTMT maintains comprehensive model cards for all AI systems. These documents include training data sources, feature engineering processes, model performance metrics, bias considerations, and limitations. Version control is implemented through a robust Git-based system, and all model updates are tracked with detailed change logs. Documentation is updated in real time alongside production deployments.

TTMT also provides a well-defined human review mechanism for automated decisions. Users can request manual review through a dedicated interface, and trained reviewers handle cases within 3–5 business days. A formal appeal and contestation process is in place, ensuring consistency and fairness in decision overrides.

In terms of privacy transparency, TTMT fully complies with CCPA requirements. The company clearly discloses AI usage in its privacy policy and provides users with an easy-to-use opt-out mechanism. All consumer requests are processed within 30 days, and users are granted access to meaningful information about the logic involved in automated decisions.

Overall, TTMT demonstrates a high level of maturity in explainability, auditability, and transparency, with strong compliance across regulatory and technical dimensions.
"""

# %%
from transparency_module import TransparencyModule

# -----------------------------
# Run Transparency Module
# -----------------------------
module = TransparencyModule()

result = module.run(document_text)

# -----------------------------
# Print Full Result
# -----------------------------
print("=== TRANSPARENCY MODULE RESULT ===")
print(result.model_dump())

# -----------------------------
# Print Summary
# -----------------------------
print("\n=== MODULE SUMMARY ===")
print("Module:", result.module_id)
print("Score:", result.module_score)
print("Risk Level:", result.risk_level)

# -----------------------------
# Print Findings
# -----------------------------
print("\n=== FINDINGS ===")

for f in result.findings:
    print("Criterion:", f.criterion_id)
    print("Score:", f.score)
    print("Evidence ID:", f.evidence.evidence_id)
    print("Evidence Type:", f.evidence.evidence_type)
    print("Excerpt:", f.evidence.excerpt)
    print("Source Section:", f.evidence.source_section)
    print("Severity:", f.severity)
    print("---")
# Out:
# LLM RAW OUTPUT:
# {
#   "findings": [
#     {
#       "criterion_id": "E4.1",
#       "description": "Explainability & Transparency",
#       "score": 1.0,
#       "evidence": {
#         "evidence_id": "E4.1",
#         "evidence_type": "policy_text",
#         "excerpt": "TTMT implements SHAP-based explanations across all production machine learning models. Feature importance scores are generated for over 98% of automated decisions, and internal systems allow full traceability from outputs back to input features and training data. In addition, TTMT provides clear, plain language explanations to end users, describing the logic, significance, and potential consequences of automated decisions in compliance with GDPR Articles 13 and 14.",
#         "source_section": "Model explainability"
#       }
#     },
#     {
#       "criterion_id": "E4.2",
#       "description": "Audit Trail Completeness and Integrity",
#       "score": 1.0,
#       "evidence": {
# ...

# %% [markdown]
# # **Performance**

# %%
# %cd /content/AI-Trust-Safety-Auditing-Agent/five-modules/performance
# !ls
# Out:
# /content/AI-Trust-Safety-Auditing-Agent/five-modules/performance
# performance_module.py  performance_rules.py   performance_scoring.py
# performance_prompt.py  performance_schema.py

# %%
document_text = """
TTMT is a technology company that deploys machine learning models to support customer risk assessment and operational decision-making.

To ensure model reliability, TTMT evaluates model performance using standard validation techniques such as confusion matrices, ROC curves, and precision-recall metrics. The company maintains a holdout dataset representing approximately 20% of the total data to validate model performance before deployment. Model accuracy is typically above 94%, and outputs are periodically compared with ground truth data.

TTMT has implemented a monitoring system that tracks model performance and data drift. Drift checks are conducted regularly, and alerts are triggered when performance degradation exceeds predefined thresholds. In some cases, retraining is initiated when significant deviations are detected, although not all retraining processes are fully automated.

The company maintains an internal dashboard that tracks key performance indicators such as accuracy, error rates, and false positive rates. However, updates to the dashboard may not always occur in real time, depending on data availability.

For AI-generated personal data, TTMT conducts validation using sampled datasets and evaluates accuracy metrics such as precision and recall. While this process is documented, it is not always performed continuously.

TTMT allows users to submit correction requests if they believe the model output is inaccurate. Most requests are resolved within regulatory timelines, although the company does not consistently analyze these requests to identify broader systemic issues. Retraining based on correction patterns is performed occasionally but is not fully standardized.

Overall, TTMT has established a structured approach to model validation and monitoring, but some processes such as automated retraining and continuous accuracy validation could be further strengthened.
"""

# %%
from performance_module import PerformanceModule

# -----------------------------
# Run Performanc Module
# -----------------------------
module = PerformanceModule()

result = module.run(document_text)

# -----------------------------
# Print Full Result
# -----------------------------
print("=== PERFORMANCE MODULE RESULT ===")
print(result.model_dump())

# -----------------------------
# Print Summary
# -----------------------------
print("\n=== MODULE SUMMARY ===")
print("Module:", result.module_id)
print("Score:", result.module_score)
print("Risk Level:", result.risk_level)

# -----------------------------
# Print Findings
# -----------------------------
print("\n=== FINDINGS ===")

for f in result.findings:
    print("Criterion:", f.criterion_id)
    print("Score:", f.score)
    print("Evidence ID:", f.evidence.evidence_id)
    print("Evidence Type:", f.evidence.evidence_type)
    print("Excerpt:", f.evidence.excerpt)
    print("Source Section:", f.evidence.source_section)
    print("Severity:", f.severity)
    print("---")
# Out:
# LLM RAW OUTPUT:
# {
#   "findings": [
#     {
#       "criterion_id": "A5.1",
#       "description": "Model Validation & Accuracy",
#       "score": 0.75,
#       "evidence": {
#         "evidence_id": "A5.1",
#         "evidence_type": "process_description",
#         "excerpt": "TTMT evaluates model performance using standard validation techniques such as confusion matrices, ROC curves, and precision-recall metrics. The company maintains a holdout dataset representing approximately 20% of the total data to validate model performance before deployment. Model accuracy is typically above 94%, and outputs are periodically compared with ground truth data.",
#         "source_section": "Paragraph 2"
#       }
#     },
#     {
#       "criterion_id": "A5.2",
#       "description": "Drift Monitoring with GDPR Accuracy Degradation Triggers",
#       "score": 0.75,
#       "evidence": {
#         "evidence_id": "A5.2",
#         "evidence_type": "process_description",
# ...
